# %% [markdown]
# <a href="https://colab.research.google.com/github/kinfe19/n8n/blob/master/Gym%20and%20meal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#gym and meal planer AI Assistant automation
